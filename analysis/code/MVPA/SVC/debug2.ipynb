# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#CV and DS

cv=pd.read_csv('/Users/aporter1350/Desktop/MSC_Alexis/analysis/output/results/SVC/acc/CV/acc.csv')

ds=pd.read_csv('/Users/aporter1350/Desktop/MSC_Alexis/analysis/output/results/SVC/acc/DS/acc.csv')

# %%
df = pd.melt(df, id_vars=['sub'], value_vars=['mixed','motor','mem'], var_name='task', value_name='acc')  
df.drop('sub', axis=1, inplace=True)
plt.figure(figsize=(15,8))
ax=sns.boxplot(x='task', y='acc', data=df)
ax.set_title('Cross Validation')
ax.set_xlabel('Test Task')
ax.set_ylabel('Accuracy')
fig=ax.get_figure()

# %%
df=ds.drop('Unnamed: 0', axis=1)
df.drop(['train_sub', 'test_sub'], axis=1, inplace=True)
plt.figure(figsize=(15,8))
ax=sns.boxplot(x='task', y='acc', data=df)
ax.axhline(.50, ls='--', color='r')
ax.set_title('Different Sub Same Task')
ax.set_xlabel('Test Task')
ax.set_ylabel('Accuracy')
fig=ax.get_figure()
#fig.savefig(outDir +'images/'+classifier+'/acc/'+analysis+'/boxplot.png', bbox_inches='tight')

# %%
ds
# Out:
#      Unnamed: 0 train_sub test_sub   task   acc
# 0             0     MSC01    MSC02  mixed  0.80
# 1             1     MSC01    MSC02  motor  0.95
# 2             2     MSC01    MSC02    mem  0.90
# 3             3     MSC01    MSC03  mixed  0.75
# 4             4     MSC01    MSC03  motor  0.90
# 5             5     MSC01    MSC03    mem  1.00
# 6             6     MSC01    MSC04  mixed  0.90
# 7             7     MSC01    MSC04  motor  1.00
# 8             8     MSC01    MSC04    mem  0.85
# 9             9     MSC01    MSC05  mixed  0.95
# 10           10     MSC01    MSC05  motor  0.90
# 11           11     MSC01    MSC05    mem  0.95
# 12           12     MSC01    MSC06  mixed  0.65
# 13           13     MSC01    MSC06  motor  0.80
# 14           14     MSC01    MSC06    mem  0.70
# 15           15     MSC01    MSC07  mixed  1.00
# 16           16     MSC01    MSC07  motor  0.95
# 17           17     MSC01    MSC07    mem  1.00
# 18           18     MSC01    MSC10  mixed  0.85
# 19           19     MSC01    MSC10  motor  1.00
# 20           20     MSC01    MSC10    mem  0.95
# 21           21     MSC02    MSC01  mixed  0.85
# 22           22     MSC02    MSC01  motor  0.80
# 23           23     MSC02    MSC01    mem  1.00
# 24           24     MSC02    MSC03  mixed  0.90
# 25           25     MSC02    MSC03  motor  0.85
# 26           26     MSC02    MSC03    mem  1.00
# 27           27     MSC02    MSC04  mixed  0.80
# 28           28     MSC02    MSC04  motor  0.90
# 29           29     MSC02    MSC04    mem  1.00
# ..          ...       ...      ...    ...   ...
# 138         138     MSC07    MSC05  mixed  0.50
# 139         139     MSC07    MSC05  motor  0.90
# 140         140     MSC07    MSC05    mem  0.90
# 141         141     MSC07    MSC06  mixed  0.55
# 142         142     MSC07    MSC06  motor  0.90
# 143         143     MSC07    MSC06    mem  0.90
# 144         144     MSC07    MSC10  mixed  0.60
# 145         145     MSC07    MSC10  motor  0.90
# 146         146     MSC07    MSC10    mem  0.95
# 147         147     MSC10    MSC01  mixed  0.65
# 148         148     MSC10    MSC01  motor  0.80
# 149         149     MSC10    MSC01    mem  1.00
# 150         150     MSC10    MSC02  mixed  0.55
# 151         151     MSC10    MSC02  motor  0.90
# 152         152     MSC10    MSC02    mem  0.95
# 153         153     MSC10    MSC03  mixed  0.60
# 154         154     MSC10    MSC03  motor  0.90
# 155         155     MSC10    MSC03    mem  1.00
# 156         156     MSC10    MSC04  mixed  0.70
# 157         157     MSC10    MSC04  motor  0.90
# 158         158     MSC10    MSC04    mem  0.95
# 159         159     MSC10    MSC05  mixed  0.65
# 160         160     MSC10    MSC05  motor  0.80
# 161         161     MSC10    MSC05    mem  0.90
# 162         162     MSC10    MSC06  mixed  0.70
# 163         163     MSC10    MSC06  motor  0.65
# 164         164     MSC10    MSC06    mem  0.85
# 165         165     MSC10    MSC07  mixed  0.55
# 166         166     MSC10    MSC07  motor  0.90
# 167         167     MSC10    MSC07    mem  0.70
#
# [168 rows x 5 columns]
