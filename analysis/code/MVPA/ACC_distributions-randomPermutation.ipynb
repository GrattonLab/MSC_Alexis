# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
#concatenate all dataframes
accTable=[]
subList=['MSC01','MSC02','MSC03','MSC04','MSC05','MSC06','MSC07','MSC08','MSC09','MSC10']
for i in subList:
    df=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/MVPA_mat/random_permutation_test/' +i +'_accRandom.csv')
    accTable.append(df)
results=pd.concat(accTable)

# %%
#results.head()
results.replace(0, np.nan, inplace=True)

# %%
results.mean(skipna=True)
# Out:
# mem      0.585833
# mixed    0.376389
# motor    0.451875
# dtype: float64

# %%
#groupby the testing variables
grouped_df=results.groupby('Row')
memTest_df=grouped_df.get_group('mem')
mixedTest_df=grouped_df.get_group('mixed')
motorTest_df=grouped_df.get_group('motor')

# %%
#univariate distribution of accuracy scores across subjects when trained on mixed
sns.distplot(memTest_df.mixed, hist=False, rug=True)
#trained on motor NOTE there are likely nans in the matlab script which is why there are 0
sns.distplot(memTest_df.motor, hist=False, rug=True)

# %%
#univariate distribution of accuracy scores across subjects when trained on mixed
sns.distplot(mixedTest_df.mem, hist=False, rug=True)
#trained on motor NOTE there are likely nans in the matlab script which is why there are 0
sns.distplot(mixedTest_df.motor, hist=False, rug=True)

# %%
#univariate distribution of accuracy scores across subjects when trained on mixed
sns.distplot(motorTest_df.mem, hist=False, rug=True)
#trained on motor NOTE there are likely nans in the matlab script which is why there are 0
sns.distplot(motorTest_df.mixed, hist=False, rug=True)

# %%
memTest_df
#motorTest_df
#mixedTest_df
# Out:
#    Row  mem  mixed  motor
# 0  mem  NaN  0.540  0.865
# 0  mem  NaN  0.690  0.680
# 0  mem  NaN  0.665  0.645
# 0  mem  NaN  0.040  0.895
# 0  mem  NaN  0.030  0.455
# 0  mem  NaN  1.000  0.005
# 0  mem  NaN  0.785  0.015
# 0  mem  NaN  0.005    NaN
# 0  mem  NaN  0.045    NaN
# 0  mem  NaN  0.260  0.305

# %%
df=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/MVPA_mat/random_permutation_test/permuted_MSC06_accRandom.csv')

# %%
df.head()
# Out:
#        C
# 0  0.000
# 1  0.480
# 2  0.075
# 3  0.960
# 4  0.360

# %%
sns.distplot(df.C, hist=False, rug=True)
