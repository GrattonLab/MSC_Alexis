# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

mem_df=pd.read_csv('/Users/aporter1350/Desktop/MSC_Alexis/analysis/output/results/logReg/acc/DS/mem_accTable_diff_sub.csv')
mem_df.set_index('Test_variables', inplace=True)


mixed_df=pd.read_csv('/Users/aporter1350/Desktop/MSC_Alexis/analysis/output/results/logReg/acc/DS/mixed_accTable_diff_sub.csv')
mixed_df.set_index('Test_variables', inplace=True)


motor_df=pd.read_csv('/Users/aporter1350/Desktop/MSC_Alexis/analysis/output/results/logReg/acc/DS/motor_accTable_diff_sub.csv')
motor_df.set_index('Test_variables', inplace=True)

# %%
sns.heatmap(mem_df, annot=True)
all_sample_title = 'Memory'
plt.title(all_sample_title, size = 15);
plt.savefig('/Users/aporter1350/Desktop/MSC_Alexis/analysis/output/images/logReg/acc/DS/mem_acc_heatmap.png', bbox_inches='tight')

# %%
ax=sns.heatmap(mixed_df, annot=True)
all_sample_title = 'Mixed'
plt.title(all_sample_title, size = 15);
plt.savefig('/Users/aporter1350/Desktop/MSC_Alexis/analysis/output/images/logReg/acc/DS/mixed_acc_heatmap.png', bbox_inches='tight')

# %%
ax=sns.heatmap(motor_df, annot=True)
all_sample_title = 'Motor'
plt.title(all_sample_title, size = 15);
plt.savefig('/Users/aporter1350/Desktop/MSC_Alexis/analysis/output/images/logReg/acc/DS/motor_acc_heatmap.png', bbox_inches='tight')
