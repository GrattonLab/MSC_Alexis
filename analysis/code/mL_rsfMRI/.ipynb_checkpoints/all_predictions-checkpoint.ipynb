# %%
import time
import classify
analysisList=['DS', 'SS', 'BS','CV']
classifierList=['SVC', 'logReg','ridge']
start=time.time()
for classifier in classifierList:
    for analysis in analysisList:
        print('Now running '+classifier+' with analysis type '+analysis)
        classify.run_prediction(classifier, analysis)
end=time.time()
print("Execution time: ",end-start)
# Out:
# Now running SVC with analysis type DS
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-33d53ba8e9eb> in <module>
#       7     for analysis in analysisList:
#       8         print('Now running '+classifier+' with analysis type '+analysis)
# ----> 9         classify.run_prediction(classifier, analysis)
#      10 end=time.time()
#      11 print("Execution time: ",end-start)
#
# ~/Desktop/MSC_Alexis/analysis/code/mL_rsfMRI/classify.py in run_prediction(classifier, analysis)
#      50         classifyCV(classifier, analysis)
#      51     elif analysis=='DS':
# ---> 52         classifyDS(classifier, analysis)
#      53     elif analysis=='SS':
#      54         classifySS(classifier, analysis)
#
# ~/Desktop/MSC_Alexis/analysis/code/mL_rsfMRI/classify.py in classifyDS(classifier, analysis)
#      64     dfDS['task']=tmp_df['task']
#      65     for index, row in dfDS.iterrows():
# ---> 66         score=model(classifier, analysis, train_sub=row['train_sub'], test_sub=row['test_sub'], train_task=row['task'], test_task=row['task'])
#      67         acc_scores_per_task.append(score)
#      68     dfDS['acc']=acc_scores_per_task
#
# ~/Desktop/MSC_Alexis/analysis/code/mL_rsfMRI/classify.py in model(classifier, analysis, train_sub, test_sub, train_task, test_task)
#     121         test_taskFC=reshape.matFiles(dataDir+test_task+'/tmask_all/'+test_sub+'_parcel_corrmat.mat')
#     122         test_restFC=reshape.matFiles(dataDir+'rest/tmask_all/'+test_sub+'_parcel_corrmat.mat')
# --> 123         ACCscores=CV_folds(clf, analysis, taskFC, restFC, test_taskFC, test_restFC)
#     124     return ACCscores
#     125 #Calculate acc of cross validation within sub within task
#
# ~/Desktop/MSC_Alexis/analysis/code/mL_rsfMRI/classify.py in CV_folds(clf, analysis, taskFC, restFC, test_taskFC, test_restFC)
#     196         for train_index, test_index in loo.split(taskFC):
#     197             Xtrain_rest, Xtest_rest=restFC[train_index], test_restFC[test_index]
# --> 198             Xtrain_task, Xtest_task=taskFC[train_index], test_taskFC[test_index]
#     199
#     200             ytrain_rest, ytest_rest=r[train_index], r[test_index]
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
import results
#results.ds_boxplot()
#results.bs_boxplot()
#results.ss_boxplot()
results.cv_modelComp()
