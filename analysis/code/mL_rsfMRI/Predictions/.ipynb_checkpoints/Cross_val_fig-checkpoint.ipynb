# %%
import reshape
import matlab.engine
import scipy.io
import pandas as pd
import numpy as np
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
thisDir = os.path.expanduser('~/Desktop/MSC_Alexis/analysis/')
Parcel_params = reshape.loadParcelParams('Gordon333',thisDir+'data/Parcel_info/')
roi_sort = np.squeeze(Parcel_params['roi_sort'])
fileFC=scipy.io.loadmat(thisDir+'data/mvpa_data/mem/MSC06_memMrest_parcel_corrmat.mat')
#Convert to numpy array
fileFC=np.array(fileFC['parcel_corrmat'])

restFC=scipy.io.loadmat(thisDir+'data/mvpa_data/mem/MSC06_parcel_corrmat.mat')
#Convert to numpy array
restFC=np.array(restFC['parcel_corrmat'])

fileSS=scipy.io.loadmat(thisDir+'data/mvpa_data/mem/MSC06_motMrest_parcel_corrmat.mat')
SS=np.array(fileSS['parcel_corrmat'])


fileDS=scipy.io.loadmat(thisDir+'data/mvpa_data/mem/MSC03_memMrest_parcel_corrmat.mat')
DS=np.array(fileDS['parcel_corrmat'])

fileBS=scipy.io.loadmat(thisDir+'data/mvpa_data/mem/MSC03_motMrest_parcel_corrmat.mat')
BS=np.array(fileBS['parcel_corrmat'])


avg_task=np.mean(fileFC,axis=2)
avg_rest=np.mean(restFC,axis=2)

# %%
fig=plt.figure(figsize=(20,30), constrained_layout=True)
plt.rcParams['figure.constrained_layout.use'] = True
gs = gridspec.GridSpec(nrows=10, ncols=4)#, wspace=0.9, hspace=0.1)
gs.update(wspace=0.05, hspace=0.4, left = 0.1, right = 0.7, bottom = 0.1, top = 0.9) 

fig.text(.15, .94, 'Same Subject',fontsize=40)
fig.text(.15, .91, 'Task',fontsize=30)
fig.text(.3, .91, 'Rest',fontsize=30)
#fig.text(.2, .64, 'Fold 1',fontsize=40)
fig.text(.45,.7, 'Same Subject', fontsize=40)
fig.text(.5, .68, 'Test Set',fontsize=40)
fig.text(.45, .66, 'Task',fontsize=30)
fig.text(.6, .66, 'Rest',fontsize=30)
#plt.arrow(.23, .62, .15, 0, width = 0.01)  
fig.text(.02, .87, 'Session 1',fontsize=30)
fig.text(.02, .79, 'Session 2',fontsize=30)
fig.text(.02, .71, 'Session 3',fontsize=30)
fig.text(.17, .61, 'Left Out Session', fontsize=30)
fig.text(.07, .54, '. . .',fontsize=30,rotation='vertical')
fig.text(.01, .46, 'Session 10',fontsize=30)

for i in range(6):
    corrmat=fileFC[:,:,i]
    if i != 3:
    # main figure plotting
        ax=fig.add_subplot(gs[i,0])
        im = ax.imshow(corrmat[roi_sort,:][:,roi_sort],cmap="jet",vmin=-.4,vmax=.4,interpolation='none')
        cbar=plt.colorbar(im)

        # add some lines between networks
        for tr in Parcel_params['transitions']:
            ax.axhline(tr,0,Parcel_params['num_rois'],color='k')
            ax.axvline(tr,0,Parcel_params['num_rois'],color='k')
        plt.setp(ax.get_xticklabels(), visible=False)
        plt.setp(ax.get_yticklabels(), visible=False)
        cbar.remove()
        
    else:
        ax=fig.add_subplot(gs[i,2])
        im = ax.imshow(corrmat[roi_sort,:][:,roi_sort],cmap="jet",vmin=-.4,vmax=.4,interpolation='none')
        cbar=plt.colorbar(im)

        # add some lines between networks
        for tr in Parcel_params['transitions']:
            ax.axhline(tr,0,Parcel_params['num_rois'],color='k')
            ax.axvline(tr,0,Parcel_params['num_rois'],color='k')
        plt.setp(ax.get_xticklabels(), visible=False)
        plt.setp(ax.get_yticklabels(), visible=False)
        cbar.remove()
for i in range(6):
    corrmat=restFC[:,:,i]
    if i!=3:
        # main figure plotting
        ax=fig.add_subplot(gs[i,1])
        im = ax.imshow(corrmat[roi_sort,:][:,roi_sort],cmap='jet',vmin=-.4,vmax=1, interpolation='none')
        cbar=plt.colorbar(im)

        # add some lines between networks
        for tr in Parcel_params['transitions']:
            ax.axhline(tr,0,Parcel_params['num_rois'],color='k')
            ax.axvline(tr,0,Parcel_params['num_rois'],color='k')
        plt.setp(ax.get_xticklabels(), visible=False)
        plt.setp(ax.get_yticklabels(), visible=False)
        cbar.remove()
    else:
        ax=fig.add_subplot(gs[i,3])
        im = ax.imshow(corrmat[roi_sort,:][:,roi_sort],cmap='jet',vmin=-.4,vmax=1, interpolation='none')
        cbar=plt.colorbar(im)

        # add some lines between networks
        for tr in Parcel_params['transitions']:
            ax.axhline(tr,0,Parcel_params['num_rois'],color='k')
            ax.axvline(tr,0,Parcel_params['num_rois'],color='k')
        plt.setp(ax.get_xticklabels(), visible=False)
        plt.setp(ax.get_yticklabels(), visible=False)
        cbar.remove()

plt.savefig(thisDir+'output/FigsFinal/CrossVal_example.png', bbox_inches='tight')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:78: UserWarning: Calling figure.constrained_layout, but figure not setup to do constrained layout.  You either called GridSpec without the fig keyword, you are using plt.subplot, or you need to call figure or subplots with the constrained_layout=True kwarg.

# %%
fig=plt.figure(figsize=(10,40), constrained_layout=True)
plt.rcParams['figure.constrained_layout.use'] = True
gs = gridspec.GridSpec(nrows=1, ncols=2)

fig.text(.23, .54, 'Task',fontsize=20)
fig.text(.65, .54, 'Rest',fontsize=20)

ax=fig.add_subplot(gs[0,0])
im = ax.imshow(avg_task[roi_sort,:][:,roi_sort],cmap='jet',vmin=-.4,vmax=.4, interpolation='none')
cbar=plt.colorbar(im)

# add some lines between networks
for tr in Parcel_params['transitions']:
    ax.axhline(tr,0,Parcel_params['num_rois'],color='k')
    ax.axvline(tr,0,Parcel_params['num_rois'],color='k')

ax.set_xticks(Parcel_params['centers'])
ax.set_yticks(Parcel_params['centers'])
ax.set_xticklabels(Parcel_params['networks'],fontsize=8)
ax.set_yticklabels(Parcel_params['networks'],fontsize=8)
plt.setp(ax.get_xticklabels(), rotation = 45, ha = 'right', rotation_mode = 'anchor')
cbar.remove()

ax=fig.add_subplot(gs[0,1])
im = ax.imshow(avg_rest[roi_sort,:][:,roi_sort],cmap='jet',vmin=-.4,vmax=1, interpolation='none')
cbar=plt.colorbar(im)

# add some lines between networks
for tr in Parcel_params['transitions']:
    ax.axhline(tr,0,Parcel_params['num_rois'],color='k')
    ax.axvline(tr,0,Parcel_params['num_rois'],color='k')

ax.set_xticks(Parcel_params['centers'])
ax.set_yticks(Parcel_params['centers'])
ax.set_xticklabels(Parcel_params['networks'],fontsize=8)
ax.set_yticklabels(Parcel_params['networks'],fontsize=8)
plt.setp(ax.get_xticklabels(), rotation = 45, ha = 'right', rotation_mode = 'anchor')
cbar.remove()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: UserWarning: Calling figure.constrained_layout, but figure not setup to do constrained layout.  You either called GridSpec without the fig keyword, you are using plt.subplot, or you need to call figure or subplots with the constrained_layout=True kwarg.

# %%
fig=plt.figure(figsize=(20,30), constrained_layout=True)
plt.rcParams['figure.constrained_layout.use'] = True
gs = gridspec.GridSpec(nrows=10, ncols=4)#, wspace=0.9, hspace=0.1)
gs.update(wspace=0.003, hspace=0.05, left = 0.1, right = 0.7, bottom = 0.1, top = 0.9) 

fig.text(.16, .95, 'Same Subject',fontsize=30)
fig.text(.16, .93, 'Different Task',fontsize=30)
fig.text(.15, .91, 'Task',fontsize=30)
fig.text(.3, .91, 'Rest',fontsize=30)
fig.text(.04, .87, 'Session 1',fontsize=20)
fig.text(.04, .79, 'Session 2',fontsize=20)
fig.text(.04, .71, 'Session 3',fontsize=20)
fig.text(.07, .61, '. . .', fontsize=30,rotation='vertical')
fig.text(.04, .54, 'Session 9',fontsize=20)
fig.text(.04, .46, 'Session 10',fontsize=20)

for i in range(6):
    corrmat=SS[:,:,i]
# main figure plotting
    ax=fig.add_subplot(gs[i,0])
    im = ax.imshow(corrmat[roi_sort,:][:,roi_sort],cmap="jet",vmin=-.4,vmax=.4,interpolation='none')
    cbar=plt.colorbar(im)

        # add some lines between networks
    for tr in Parcel_params['transitions']:
        ax.axhline(tr,0,Parcel_params['num_rois'],color='k')
        ax.axvline(tr,0,Parcel_params['num_rois'],color='k')
    plt.setp(ax.get_xticklabels(), visible=False)
    plt.setp(ax.get_yticklabels(), visible=False)
    cbar.remove()

for i in range(6):
    corrmat=restFC[:,:,i]
    # main figure plotting
    ax=fig.add_subplot(gs[i,1])
    im = ax.imshow(corrmat[roi_sort,:][:,roi_sort],cmap='jet',vmin=-.4,vmax=1, interpolation='none')
    cbar=plt.colorbar(im)

    # add some lines between networks
    for tr in Parcel_params['transitions']:
        ax.axhline(tr,0,Parcel_params['num_rois'],color='k')
        ax.axvline(tr,0,Parcel_params['num_rois'],color='k')
    plt.setp(ax.get_xticklabels(), visible=False)
    plt.setp(ax.get_yticklabels(), visible=False)
    cbar.remove()

#plt.savefig(thisDir+'output/FigsFinal/same_sub_example.png', bbox_inches='tight')

# %%
import masterClass
masterClass.classifyCV()
masterClass.classifyDS()
masterClass.classifySS()
masterClass.classifyBS()
#Classify All tasks with rest split 
masterClass.classifyAll()
