# %%
#Aim 1 and Aim 2 results
#authentication
import masterClass
#masterClass.classifyCV()
#masterClass.classifyDS()
#masterClass.classifySS()
#masterClass.classifyBS()
#Classify All tasks with rest split 
masterClass.classifyAll()

# %%
numComponents=np.logspace(2, 4.7, num=50,dtype=int)

# %%
#Classify All using a PCA approach
#Need to vet this process to ensure it is correct
import masterClass
import pandas as pd
import numpy as np
pca50=pd.DataFrame()
#50% variance explained
#numComponents=[.05,.1,.15,.2,.25,.3,.35,.4,.45,.5,.55,.6,.65,.7,.75,.8,.85,.9]
num=1
while num<40:
#for num in numComponents:
    tmp=masterClass.classifyAll_wPCA(num,.5)
    tmp['numComponent']=num
    pca50=pd.concat([pca50,tmp])
    num=num+1
    print('now at ', num)
pca50.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/acc/ALL/pca50_acc.csv',index=False)
# Out:
# now at  2
# now at  3
# now at  4
# now at  5
# now at  6
# now at  7
# now at  8
# now at  9
# now at  10
# now at  11
# now at  12
# now at  13
# now at  14
# now at  15
# now at  16
# now at  17
# now at  18
# now at  19
# now at  20
# now at  21
# now at  22
# now at  23
# now at  24
# now at  25
# now at  26
# now at  27
# now at  28
# now at  29
# now at  30
# now at  31
# now at  32
# now at  33
# now at  34
# now at  35
# now at  36
# now at  37
# now at  38
# now at  39
# now at  40

# %%
#Feature Selection of networks
import featSelection
import sys
import os
import pandas as pd
import numpy as np
thisDir = os.path.expanduser('~/Desktop/MSC_Alexis/analysis/')
outDir = thisDir + 'output/results/'
subDir=outDir+'subNetwork/'
allDF=pd.DataFrame()
CVDF=pd.DataFrame()
SSDF=pd.DataFrame()
DSDF=pd.DataFrame()
BSDF=pd.DataFrame()
netRoi=dict([('unassign',14808),('default', 10824),('visual',8736),('fp', 4620),('dan',5264),('van',3151),('salience', 494),('co', 4060),('sm', 2375),('sm-lat', 316),('auditory', 564),('pmn',45),('pon',21)])
for network in netRoi:
    print('Now running for network '+network)
    #tmpCV=featSelection.classifyCV(network)
    #tmpCV['network']=network
    #tmpCV['feature']=netRoi[network]
    #CVDF=pd.concat([CVDF,tmpCV])
    #tmpDS=featSelection.classifyDS(network)
    #tmpDS['network']=network
    #tmpDS['feature']=netRoi[network]
    #DSDF=pd.concat([DSDF,tmpDS])
    #tmpSS=featSelection.classifySS(network)
    #tmpSS['network']=network
    #tmpSS['feature']=netRoi[network]
    #SSDF=pd.concat([SSDF,tmpSS])
    #tmpBS=featSelection.classifyBS(network)
    #tmpBS['network']=network
    #tmpBS['feature']=netRoi[network]
    #BSDF=pd.concat([BSDF,tmpBS])
    tmp=featSelection.classifyAll(network)
    tmp['network']=network
    tmp['feature']=netRoi[network]
    allDF=pd.concat([allDF,tmp])
#DSDF.to_csv(subDir+'DS/acc.csv',index=False)
#SSDF.to_csv(subDir+'SS/acc.csv',index=False)
#BSDF.to_csv(subDir+'BS/acc.csv',index=False)
#CVDF.to_csv(subDir+'CV/acc.csv',index=False)
allDF.to_csv(subDir+'ALL/acc.csv',index=False)
# Out:
# Now running for network unassign
# Now running for network default
# Now running for network visual
# Now running for network fp
# Now running for network dan
# Now running for network van
# Now running for network salience
# Now running for network co
# Now running for network sm
# Now running for network sm-lat
# Now running for network auditory
# Now running for network pmn
# Now running for network pon

# %%
#Permutation
#SSmOS_CVmDS
import SSmOS
import pandas as pd
CVmDS_df=pd.DataFrame()
for i in range(1000):
    DS=SSmOS.CVmDS()
    CVmDS_df=pd.concat([CVmDS_df,DS])
CVmDS_df.to_csv('~/Desktop/MSC_Alexis/analysis/output/results/permutation/CVmDS_acc.csv',index=False)

# %%
#Permutation
#SSmOS_SSmBS
import SSmOS
import pandas as pd
SSmBS_df=pd.DataFrame()
for i in range(1000):
    SS=SSmOS.SSmBS()
    SSmBS_df=pd.concat([SSmBS_df, SS])
SSmBS_df.to_csv('~/Desktop/MSC_Alexis/analysis/output/results/permutation/SSmBS_acc.csv',index=False)

# %%
#Permutation different task compared to same task
#STmDT_CVmSS
import DTmST
#DTmST.DSmBS()
DTmST.CVmSS()

# %%
#Permutation different sub compared to same sub using all data for training
import SSmOS
#All tasks
SSmOS.classifyScores()

# %%
#permutation testing on each analysis CV SS DS BS and ALL separately 1000 times
import permutation
permutation.permuteProcess()

# %%
#Manipulating Frames
import manFrames
manFrames.storeResults()

# %%
#Manipulating Days 
import manDays
manDays.runDays()

# %%
#Group avg classification Train 7 subs test 1 sub same task v new task
import groupAvg
#splits up training tasks and testing tasks. Bins all sessions together
groupAvg.groupApp()
#seperates training and testing via sessions. Leave one sub out cv per session
groupAvg.allTask()

# %%
import reshape
import os
import sys
taskList=['glass','semantic', 'motor','mem','rest']

thisDir = os.path.expanduser('~/Desktop/MSC_Alexis/analysis/')
dataDir = thisDir + 'data/mvpa_data/'
#Only using subs with full 10 sessions
subList=['MSC01','MSC02','MSC03','MSC04','MSC05','MSC06','MSC07','MSC10']
for sub in subList:
    for task in taskList:
        tmp=reshape.matFiles(dataDir+task+'/'+sub+'_parcel_corrmat.mat')
        print(tmp.shape, ' number of sessions for ', sub, ' in task ', task)
# Out:
# (10, 55278)  number of sessions for  MSC01  in task  glass
# (10, 55278)  number of sessions for  MSC01  in task  semantic
# (10, 55278)  number of sessions for  MSC01  in task  motor
# (10, 55278)  number of sessions for  MSC01  in task  mem
# (10, 55278)  number of sessions for  MSC01  in task  rest
# (10, 55278)  number of sessions for  MSC02  in task  glass
# (10, 55278)  number of sessions for  MSC02  in task  semantic
# (10, 55278)  number of sessions for  MSC02  in task  motor
# (10, 55278)  number of sessions for  MSC02  in task  mem
# (10, 55278)  number of sessions for  MSC02  in task  rest
# (10, 55278)  number of sessions for  MSC03  in task  glass
# (10, 55278)  number of sessions for  MSC03  in task  semantic
# (10, 55278)  number of sessions for  MSC03  in task  motor
# (10, 55278)  number of sessions for  MSC03  in task  mem
# (10, 55278)  number of sessions for  MSC03  in task  rest
# (10, 55278)  number of sessions for  MSC04  in task  glass
# (10, 55278)  number of sessions for  MSC04  in task  semantic
# (10, 55278)  number of sessions for  MSC04  in task  motor
# (10, 55278)  number of sessions for  MSC04  in task  mem
# (10, 55278)  number of sessions for  MSC04  in task  rest
# (10, 55278)  number of sessions for  MSC05  in task  glass
# (10, 55278)  number of sessions for  MSC05  in task  semantic
# (10, 55278)  number of sessions for  MSC05  in task  motor
# (10, 55278)  number of sessions for  MSC05  in task  mem
# (10, 55278)  number of sessions for  MSC05  in task  rest
# (9, 55278)  number of sessions for  MSC06  in task  glass
# (10, 55278)  number of sessions for  MSC06  in task  semantic
# (10, 55278)  number of sessions for  MSC06  in task  motor
# (10, 55278)  number of sessions for  MSC06  in task  mem
# (10, 55278)  number of sessions for  MSC06  in task  rest
# (10, 55278)  number of sessions for  MSC07  in task  glass
# (10, 55278)  number of sessions for  MSC07  in task  semantic
# (10, 55278)  number of sessions for  MSC07  in task  motor
# (10, 55278)  number of sessions for  MSC07  in task  mem
# (10, 55278)  number of sessions for  MSC07  in task  rest
# (10, 55278)  number of sessions for  MSC10  in task  glass
# (10, 55278)  number of sessions for  MSC10  in task  semantic
# (10, 55278)  number of sessions for  MSC10  in task  motor
# (10, 55278)  number of sessions for  MSC10  in task  mem
# (10, 55278)  number of sessions for  MSC10  in task  rest

# %%
#Some Block analysis
#CO-CO, CO-FP, CO-DMN
network=['co','fp','default']
import block_featSelection
block_featSelection.Net2Net()
block_featSelection.subNetAll()
"""
for i in network:

    block_featSelection.classifyCV(i,'co')
    block_featSelection.classifyDS(i,'co')
    block_featSelection.classifySS(i,'co')
    block_featSelection.classifyBS(i,'co')
"""
# Out:
# "\nfor i in network:\n\n    block_featSelection.classifyCV(i,'co')\n    block_featSelection.classifyDS(i,'co')\n    block_featSelection.classifySS(i,'co')\n    block_featSelection.classifyBS(i,'co')\n"

# %%
import wtn_btw_netSelection

wtn_btw_netSelection.classifyWTN()

wtn_btw_netSelection.classifyBTW()

# %%
import permuteROI
permuteROI.classifyAll()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0d765aeb7f72> in <module>
#       1 import permuteROI
# ----> 2 permuteROI.classifyAll()
#       3
#
# ~/Desktop/MSC_Alexis/analysis/code/mL_rsfMRI/Predictions/permuteROI.py in classifyAll()
#      56
#      57     for network in netRoi:
# ---> 58         df=modelAll(network)
#      59         df['feature']=network
#      60         #df['network']=network
#
# ~/Desktop/MSC_Alexis/analysis/code/mL_rsfMRI/Predictions/permuteROI.py in modelAll(network)
#      96         restFC=np.reshape(restFC,(10,4,55278)) #reshape to gather correct days
#      97
# ---> 98         test_taskFC,test_restFC=reshape.AllSubFiles(test_sub)
#      99
#     100         #return taskFC,restFC, test_taskFC,test_restFC
#
# ~/Desktop/MSC_Alexis/analysis/code/mL_rsfMRI/Predictions/reshape.py in AllSubFiles(test_sub)
#     752     c_restFC=matFiles(dataDir+'rest/corrmats_timesplit/fourths/'+test_sub[2]+'_parcel_corrmat.mat')
#     753
# --> 754     d_memFC=matFiles(dataDir+'mem/'+test_sub[3]+'_parcel_corrmat.mat')
#     755     d_semFC=matFiles(dataDir+'semantic/'+test_sub[3]+'_parcel_corrmat.mat')
#     756     d_glassFC=matFiles(dataDir+'glass/'+test_sub[3]+'_parcel_corrmat.mat')
#
# ~/Desktop/MSC_Alexis/analysis/code/mL_rsfMRI/Predictions/reshape.py in matFiles(df)
#      27     nrois=333
#      28     #Load FC file
# ---> 29     fileFC=scipy.io.loadmat(df)
#      30
#      31     #Convert to numpy array
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     224     with _open_file_context(file_name, appendmat) as f:
#     225         MR, _ = mat_reader_factory(f, **kwargs)
# --> 226         matfile_dict = MR.get_variables(variable_names)
#     227
#     228     if mdict is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in get_variables(self, variable_names)
#     331                 continue
#     332             try:
# --> 333                 res = self.read_var_array(hdr, process)
#     334             except MatReadError as err:
#     335                 warnings.warn(
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in read_var_array(self, header, process)
#     291            `process`.
#     292         '''
# --> 293         return self._matrix_reader.array_from_header(header, process)
#     294
#     295     def get_variables(self, variable_names=None):
#
# KeyboardInterrupt:

# %%
#Random feature selection 
import numpy as np
import featSelect_speed
featSelect_speed.runScript()
# Out:
# Finished with 0 in iteration 100
# Finished with 1 in iteration 100

# %%
subList=['MSC01','MSC02','MSC03','MSC04','MSC05','MSC06','MSC07','MSC10']
import permuteROI
for sub in subList:
    res=permuteROI.NULLmodelAll_byRow(sub)
    res.tofile('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/permutation/ALL/subs/'+sub+'_NULLRow.csv', sep = ',')

# %%
import quest_all_rdmNet as q
q.run_all()
# Out:
# Finished with 0iteration out of 1000
# Finished with 1iteration out of 1000
# Finished with 2iteration out of 1000
# Finished with 3iteration out of 1000
# Finished with 4iteration out of 1000
# Finished with 5iteration out of 1000
# Finished with 6iteration out of 1000
# Finished with 7iteration out of 1000
# Finished with 8iteration out of 1000
# Finished with 9iteration out of 1000
# Finished with 10iteration out of 1000
# Finished with 11iteration out of 1000
# Finished with 12iteration out of 1000
# Finished with 13iteration out of 1000
# Finished with 14iteration out of 1000
# Finished with 15iteration out of 1000
# Finished with 16iteration out of 1000
# Finished with 17iteration out of 1000
# Finished with 18iteration out of 1000
# Finished with 19iteration out of 1000
# Finished with 20iteration out of 1000
# Finished with 21iteration out of 1000
# Finished with 22iteration out of 1000
# Finished with 23iteration out of 1000
# Finished with 24iteration out of 1000
# Finished with 25iteration out of 1000
# Finished with 26iteration out of 1000
# Finished with 27iteration out of 1000
# Finished with 28iteration out of 1000
# Finished with 29iteration out of 1000
# Finished with 30iteration out of 1000
# Finished with 31iteration out of 1000
# Finished with 32iteration out of 1000
# Finished with 33iteration out of 1000
# Finished with 34iteration out of 1000
# Finished with 35iteration out of 1000
# Finished with 36iteration out of 1000
# Finished with 37iteration out of 1000
# Finished with 38iteration out of 1000
# Finished with 39iteration out of 1000
# Finished with 40iteration out of 1000
# Finished with 41iteration out of 1000
# Finished with 42iteration out of 1000
# Finished with 43iteration out of 1000
# Finished with 44iteration out of 1000
# Finished with 45iteration out of 1000
# Finished with 46iteration out of 1000
# Finished with 47iteration out of 1000
# Finished with 48iteration out of 1000
# Finished with 49iteration out of 1000
# Finished with 50iteration out of 1000
# Finished with 51iteration out of 1000
# Finished with 52iteration out of 1000
# Finished with 53iteration out of 1000
# Finished with 54iteration out of 1000
# Finished with 55iteration out of 1000
# Finished with 56iteration out of 1000
# Finished with 57iteration out of 1000
# Finished with 58iteration out of 1000
# Finished with 59iteration out of 1000
# Finished with 60iteration out of 1000
# Finished with 61iteration out of 1000
# Finished with 62iteration out of 1000
# Finished with 63iteration out of 1000
# Finished with 64iteration out of 1000
# Finished with 65iteration out of 1000
# Finished with 66iteration out of 1000
# Finished with 67iteration out of 1000
# Finished with 68iteration out of 1000
# Finished with 69iteration out of 1000
# Finished with 70iteration out of 1000
# Finished with 71iteration out of 1000
# Finished with 72iteration out of 1000
# Finished with 73iteration out of 1000
# Finished with 74iteration out of 1000
# Finished with 75iteration out of 1000
# Finished with 76iteration out of 1000
# Finished with 77iteration out of 1000
# Finished with 78iteration out of 1000
# Finished with 79iteration out of 1000
# Finished with 80iteration out of 1000
# Finished with 81iteration out of 1000
# Finished with 82iteration out of 1000
# Finished with 83iteration out of 1000
# Finished with 84iteration out of 1000
# Finished with 85iteration out of 1000
# Finished with 86iteration out of 1000
# Finished with 87iteration out of 1000
# Finished with 88iteration out of 1000
# Finished with 89iteration out of 1000
# Finished with 90iteration out of 1000
# Finished with 91iteration out of 1000
# Finished with 92iteration out of 1000
# Finished with 93iteration out of 1000
# Finished with 94iteration out of 1000
# Finished with 95iteration out of 1000
# Finished with 96iteration out of 1000
# Finished with 97iteration out of 1000
# Finished with 98iteration out of 1000
# Finished with 99iteration out of 1000
# Finished with 100iteration out of 1000
# Finished with 101iteration out of 1000
# Finished with 102iteration out of 1000
# Finished with 103iteration out of 1000
# Finished with 104iteration out of 1000
# Finished with 105iteration out of 1000
# Finished with 106iteration out of 1000
# Finished with 107iteration out of 1000
# Finished with 108iteration out of 1000
# Finished with 109iteration out of 1000
# Finished with 110iteration out of 1000
# Finished with 111iteration out of 1000
# Finished with 112iteration out of 1000
# Finished with 113iteration out of 1000
# Finished with 114iteration out of 1000
# Finished with 115iteration out of 1000
# Finished with 116iteration out of 1000
# Finished with 117iteration out of 1000
# Finished with 118iteration out of 1000
# Finished with 119iteration out of 1000
# Finished with 120iteration out of 1000
# Finished with 121iteration out of 1000
# Finished with 122iteration out of 1000
# Finished with 123iteration out of 1000
# Finished with 124iteration out of 1000
# Finished with 125iteration out of 1000
# Finished with 126iteration out of 1000
# Finished with 127iteration out of 1000
# Finished with 128iteration out of 1000
# Finished with 129iteration out of 1000
# Finished with 130iteration out of 1000
# Finished with 131iteration out of 1000
# Finished with 132iteration out of 1000
# Finished with 133iteration out of 1000
# Finished with 134iteration out of 1000
# Finished with 135iteration out of 1000
# Finished with 136iteration out of 1000
# Finished with 137iteration out of 1000
# Finished with 138iteration out of 1000
# Finished with 139iteration out of 1000
# Finished with 140iteration out of 1000
# Finished with 141iteration out of 1000
# Finished with 142iteration out of 1000
# Finished with 143iteration out of 1000
# Finished with 144iteration out of 1000
# Finished with 145iteration out of 1000
# Finished with 146iteration out of 1000
# Finished with 147iteration out of 1000
# Finished with 148iteration out of 1000
# Finished with 149iteration out of 1000
# Finished with 150iteration out of 1000
# Finished with 151iteration out of 1000
# Finished with 152iteration out of 1000
# Finished with 153iteration out of 1000
# Finished with 154iteration out of 1000
# Finished with 155iteration out of 1000
# Finished with 156iteration out of 1000
# Finished with 157iteration out of 1000
# Finished with 158iteration out of 1000
# Finished with 159iteration out of 1000
# Finished with 160iteration out of 1000
# Finished with 161iteration out of 1000
# Finished with 162iteration out of 1000
# Finished with 163iteration out of 1000
# Finished with 164iteration out of 1000
# Finished with 165iteration out of 1000
# Finished with 166iteration out of 1000
# Finished with 167iteration out of 1000
# Finished with 168iteration out of 1000
# Finished with 169iteration out of 1000
# Finished with 170iteration out of 1000
# Finished with 171iteration out of 1000
# Finished with 172iteration out of 1000
# Finished with 173iteration out of 1000
# Finished with 174iteration out of 1000
# Finished with 175iteration out of 1000
# Finished with 176iteration out of 1000
# Finished with 177iteration out of 1000
# Finished with 178iteration out of 1000
# Finished with 179iteration out of 1000
# Finished with 180iteration out of 1000
# Finished with 181iteration out of 1000
# Finished with 182iteration out of 1000
# Finished with 183iteration out of 1000
# Finished with 184iteration out of 1000
# Finished with 185iteration out of 1000
# Finished with 186iteration out of 1000
# Finished with 187iteration out of 1000
# Finished with 188iteration out of 1000
# Finished with 189iteration out of 1000
# Finished with 190iteration out of 1000
# Finished with 191iteration out of 1000
# Finished with 192iteration out of 1000
# Finished with 193iteration out of 1000
# Finished with 194iteration out of 1000
# Finished with 195iteration out of 1000
# Finished with 196iteration out of 1000
# Finished with 197iteration out of 1000
# Finished with 198iteration out of 1000
# Finished with 199iteration out of 1000
# Finished with 200iteration out of 1000
# Finished with 201iteration out of 1000
# Finished with 202iteration out of 1000
# Finished with 203iteration out of 1000
# Finished with 204iteration out of 1000
# Finished with 205iteration out of 1000
# Finished with 206iteration out of 1000
# Finished with 207iteration out of 1000
# Finished with 208iteration out of 1000
# Finished with 209iteration out of 1000
# Finished with 210iteration out of 1000
# Finished with 211iteration out of 1000
# Finished with 212iteration out of 1000
# Finished with 213iteration out of 1000
# Finished with 214iteration out of 1000
# Finished with 215iteration out of 1000
# Finished with 216iteration out of 1000
# Finished with 217iteration out of 1000
# Finished with 218iteration out of 1000
# Finished with 219iteration out of 1000
# Finished with 220iteration out of 1000
# Finished with 221iteration out of 1000
# Finished with 222iteration out of 1000
# Finished with 223iteration out of 1000
# Finished with 224iteration out of 1000
# Finished with 225iteration out of 1000
# Finished with 226iteration out of 1000
# Finished with 227iteration out of 1000
# Finished with 228iteration out of 1000
# Finished with 229iteration out of 1000
# Finished with 230iteration out of 1000
# Finished with 231iteration out of 1000
# Finished with 232iteration out of 1000
# Finished with 233iteration out of 1000
# Finished with 234iteration out of 1000
# Finished with 235iteration out of 1000
# Finished with 236iteration out of 1000
# Finished with 237iteration out of 1000
# Finished with 238iteration out of 1000
# Finished with 239iteration out of 1000
# Finished with 240iteration out of 1000
# Finished with 241iteration out of 1000
# Finished with 242iteration out of 1000
# Finished with 243iteration out of 1000
# Finished with 244iteration out of 1000
# Finished with 245iteration out of 1000
# Finished with 246iteration out of 1000
# Finished with 247iteration out of 1000
# Finished with 248iteration out of 1000
# Finished with 249iteration out of 1000
# Finished with 250iteration out of 1000
# Finished with 251iteration out of 1000
# Finished with 252iteration out of 1000
# Finished with 253iteration out of 1000
# Finished with 254iteration out of 1000
# Finished with 255iteration out of 1000
# Finished with 256iteration out of 1000
# Finished with 257iteration out of 1000
# Finished with 258iteration out of 1000
# Finished with 259iteration out of 1000
# Finished with 260iteration out of 1000
# Finished with 261iteration out of 1000
# Finished with 262iteration out of 1000
# Finished with 263iteration out of 1000
# Finished with 264iteration out of 1000
# Finished with 265iteration out of 1000
# Finished with 266iteration out of 1000
# Finished with 267iteration out of 1000
# Finished with 268iteration out of 1000
# Finished with 269iteration out of 1000
# Finished with 270iteration out of 1000
# Finished with 271iteration out of 1000
# Finished with 272iteration out of 1000
# Finished with 273iteration out of 1000
# Finished with 274iteration out of 1000
# Finished with 275iteration out of 1000
# Finished with 276iteration out of 1000
# Finished with 277iteration out of 1000
# Finished with 278iteration out of 1000
# Finished with 279iteration out of 1000
# Finished with 280iteration out of 1000
# Finished with 281iteration out of 1000
# Finished with 282iteration out of 1000
# Finished with 283iteration out of 1000
# Finished with 284iteration out of 1000
# Finished with 285iteration out of 1000
# Finished with 286iteration out of 1000
# Finished with 287iteration out of 1000
# Finished with 288iteration out of 1000
# Finished with 289iteration out of 1000
# Finished with 290iteration out of 1000
# Finished with 291iteration out of 1000
# Finished with 292iteration out of 1000
# Finished with 293iteration out of 1000
# Finished with 294iteration out of 1000
# Finished with 295iteration out of 1000
# Finished with 296iteration out of 1000
# Finished with 297iteration out of 1000
# Finished with 298iteration out of 1000
# Finished with 299iteration out of 1000
# Finished with 300iteration out of 1000
# Finished with 301iteration out of 1000
# Finished with 302iteration out of 1000
# Finished with 303iteration out of 1000
# Finished with 304iteration out of 1000
# Finished with 305iteration out of 1000
# Finished with 306iteration out of 1000
# Finished with 307iteration out of 1000
# Finished with 308iteration out of 1000
# Finished with 309iteration out of 1000
# Finished with 310iteration out of 1000
# Finished with 311iteration out of 1000
# Finished with 312iteration out of 1000
# Finished with 313iteration out of 1000
# Finished with 314iteration out of 1000
# Finished with 315iteration out of 1000
# Finished with 316iteration out of 1000
# Finished with 317iteration out of 1000
# Finished with 318iteration out of 1000
# Finished with 319iteration out of 1000
# Finished with 320iteration out of 1000
# Finished with 321iteration out of 1000
# Finished with 322iteration out of 1000
# Finished with 323iteration out of 1000
# Finished with 324iteration out of 1000
# Finished with 325iteration out of 1000
# Finished with 326iteration out of 1000
# Finished with 327iteration out of 1000
# Finished with 328iteration out of 1000
# Finished with 329iteration out of 1000
# Finished with 330iteration out of 1000
# Finished with 331iteration out of 1000
# Finished with 332iteration out of 1000
# Finished with 333iteration out of 1000
# Finished with 334iteration out of 1000
# Finished with 335iteration out of 1000
# Finished with 336iteration out of 1000
# Finished with 337iteration out of 1000
# Finished with 338iteration out of 1000
# Finished with 339iteration out of 1000
# Finished with 340iteration out of 1000
# Finished with 341iteration out of 1000
# Finished with 342iteration out of 1000
# Finished with 343iteration out of 1000
# Finished with 344iteration out of 1000
# Finished with 345iteration out of 1000
# Finished with 346iteration out of 1000
# Finished with 347iteration out of 1000
# Finished with 348iteration out of 1000
# Finished with 349iteration out of 1000
# Finished with 350iteration out of 1000
# Finished with 351iteration out of 1000
# Finished with 352iteration out of 1000
# Finished with 353iteration out of 1000
# Finished with 354iteration out of 1000
# Finished with 355iteration out of 1000
# Finished with 356iteration out of 1000
# Finished with 357iteration out of 1000
# Finished with 358iteration out of 1000
# Finished with 359iteration out of 1000
# Finished with 360iteration out of 1000
# Finished with 361iteration out of 1000
# Finished with 362iteration out of 1000
# Finished with 363iteration out of 1000
# Finished with 364iteration out of 1000
# Finished with 365iteration out of 1000
# Finished with 366iteration out of 1000
# Finished with 367iteration out of 1000
# Finished with 368iteration out of 1000
# Finished with 369iteration out of 1000
# Finished with 370iteration out of 1000
# Finished with 371iteration out of 1000
# Finished with 372iteration out of 1000
# Finished with 373iteration out of 1000
# Finished with 374iteration out of 1000
# Finished with 375iteration out of 1000
# Finished with 376iteration out of 1000
# Finished with 377iteration out of 1000
# Finished with 378iteration out of 1000
# Finished with 379iteration out of 1000
# Finished with 380iteration out of 1000
# Finished with 381iteration out of 1000
# Finished with 382iteration out of 1000
# Finished with 383iteration out of 1000
# Finished with 384iteration out of 1000
# Finished with 385iteration out of 1000
# Finished with 386iteration out of 1000
# Finished with 387iteration out of 1000
# Finished with 388iteration out of 1000
# Finished with 389iteration out of 1000
# Finished with 390iteration out of 1000
# Finished with 391iteration out of 1000
# Finished with 392iteration out of 1000
# Finished with 393iteration out of 1000
# Finished with 394iteration out of 1000
# Finished with 395iteration out of 1000
# Finished with 396iteration out of 1000
# Finished with 397iteration out of 1000
