# %%
import pandas as pd
import numpy as np
import os
import sys
# Initialization of directory information:
thisDir = os.path.expanduser('~/Desktop/MSC_Alexis/analysis/')
outDir = thisDir + 'output/mL/results/ridge/permutation/'
regDir = thisDir + 'output/mL/results/ridge/acc/'


CV=pd.read_csv(regDir+'CV/acc.csv')
CV=pd.melt(CV,id_vars=['sub'],value_vars=['mixed','motor','mem'], var_name='train_task', value_name='acc')

SS=pd.read_csv(regDir+'SS/acc.csv',usecols=[1,2,3,4])
BS=pd.read_csv(regDir+'BS/acc.csv',usecols=[1,2,3,4,5])
DS=pd.read_csv(regDir+'DS/acc.csv',usecols=[1,2,3,4])


#CV-SS
between=pd.read_csv(outDir+'SS/STmDT_acc.csv')
#DS-BS
within=pd.read_csv(outDir+'BS/STmDT_acc.csv')

# %%
#prepping BS and SS
BS.rename(columns={'train_sub':'sub'},inplace=True)

diff_task=SS.merge(BS,how='left',on=['train_task','test_task','sub'],suffixes=('','_BS'))
#SS-OS
diff_task['diff'] =diff_task.acc-diff_task.acc_BS 
#subset so we only average the SS-OS per train/test tasks
DT=diff_task[['train_task','test_task','diff']]
#take average
diffDT=DT.groupby(['train_task','test_task']).mean()
diffDT.reset_index(inplace=True)
DS.rename(columns={'train_sub':'sub'},inplace=True)
same_task=CV.merge(DS,how='left',on=['task','sub'],suffixes=('','_DS'))
#SS-OS
same_task['diff'] =same_task.acc-same_task.acc_DS 
#subset so we only average the SS-OS per train/test tasks
ST=same_task[['task','diff']]
#take average
diffST=ST.groupby(['task']).mean()
diffST.reset_index(inplace=True)

diffDT['TrTe'] = diffDT.train_task.map(str) + "_" + diffDT.test_task
DT=diffDT[['TrTe','diff']]
DT.set_index('TrTe',inplace=True)
# Out:
#      sub  mixed  motor   mem
# 0  MSC01   0.95   1.00  1.00
# 1  MSC02   0.90   0.95  1.00
# 2  MSC03   1.00   0.95  1.00
# 3  MSC04   1.00   1.00  1.00
# 4  MSC05   1.00   1.00  1.00
# 5  MSC06   1.00   1.00  1.00
# 6  MSC07   1.00   1.00  1.00
# 7  MSC10   0.95   0.95  0.95

# %%
SS.head()
# Out:
#   train_task test_task    sub    acc
# 0      mixed     motor  MSC01  0.995
# 1      mixed       mem  MSC01  0.935
# 2      motor     mixed  MSC01  0.815
# 3      motor       mem  MSC01  0.650
# 4        mem     mixed  MSC01  0.945

# %%
same_task=SS.merge(CV, how='left', on=['train_task','sub'],suffixes=('','_CV'))

# %%
diff_task=BS.merge(DS,how='left',on=['train_task','sub','test_sub'],suffixes=('','_DS'))
diff_task['diff']=diff_task['acc_DS']-diff_task['acc']
#diff sub same task - diff sub diff task 
STmDT=diff_task[['train_task','test_task','diff']]
# Out:
#    train_task test_task    sub    acc
# 0       mixed     motor  MSC01  0.995
# 1       mixed       mem  MSC01  0.935
# 2       motor     mixed  MSC01  0.815
# 3       motor       mem  MSC01  0.650
# 4         mem     mixed  MSC01  0.945
# 5         mem     motor  MSC01  1.000
# 6       mixed     motor  MSC02  0.750
# 7       mixed       mem  MSC02  0.830
# 8       motor     mixed  MSC02  0.500
# 9       motor       mem  MSC02  0.500
# 10        mem     mixed  MSC02  0.730
# 11        mem     motor  MSC02  0.630
# 12      mixed     motor  MSC03  1.000
# 13      mixed       mem  MSC03  0.805
# 14      motor     mixed  MSC03  0.545
# 15      motor       mem  MSC03  0.585
# 16        mem     mixed  MSC03  0.635
# 17        mem     motor  MSC03  0.875
# 18      mixed     motor  MSC04  0.950
# 19      mixed       mem  MSC04  0.960
# 20      motor     mixed  MSC04  0.585
# 21      motor       mem  MSC04  0.655
# 22        mem     mixed  MSC04  0.915
# 23        mem     motor  MSC04  0.900
# 24      mixed     motor  MSC05  0.965
# 25      mixed       mem  MSC05  1.000
# 26      motor     mixed  MSC05  0.560
# 27      motor       mem  MSC05  0.790
# 28        mem     mixed  MSC05  0.845
# 29        mem     motor  MSC05  1.000
# 30      mixed     motor  MSC06  0.915
# 31      mixed       mem  MSC06  1.000
# 32      motor     mixed  MSC06  0.600
# 33      motor       mem  MSC06  0.745
# 34        mem     mixed  MSC06  0.755
# 35        mem     motor  MSC06  0.910
# 36      mixed     motor  MSC07  0.830
# 37      mixed       mem  MSC07  0.900
# 38      motor     mixed  MSC07  0.550
# 39      motor       mem  MSC07  0.500
# 40        mem     mixed  MSC07  0.885
# 41        mem     motor  MSC07  0.785
# 42      mixed     motor  MSC10  0.905
# 43      mixed       mem  MSC10  0.965
# 44      motor     mixed  MSC10  0.505
# 45      motor       mem  MSC10  0.635
# 46        mem     mixed  MSC10  0.815
# 47        mem     motor  MSC10  0.910
