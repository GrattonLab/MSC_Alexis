# %%
import sys
import os
from scipy import stats
import pandas as pd
import numpy as np
import seaborn as sns
import random
thisDir = os.path.expanduser('~/Desktop/MSC_Alexis/analysis/')
dataDir = thisDir + 'data/mvpa_data/'
outDir = thisDir + 'output/mL/results/ridge/acc/'
import classification
subDir=thisDir+'output/subNetwork/'
randDir=thisDir+'output/randomIdx/results/ridge/acc/'
netList=['unassign','default', 'visual','fp','dan','van','salience','co','sm','sm-lat', 'auditory','pmn','pon']
feature=[14808,10824,8736, 4620,5264,3151, 484, 4060, 2375,316, 564,45,21]
netRoi=dict([('unassign',14808),('default', 10824),('visual',8736),('fp', 4620),('dan',5264),('van',3151),('salience', 484),('co', 4060),('sm', 2375),('sm-lat', 316),('auditory', 564),('pmn',45),('pon',21)])
taskList=['mixed','mem','motor']
subList=['MSC01','MSC02','MSC03','MSC04','MSC05','MSC06','MSC07','MSC10']


permSS=pd.read_csv(thisDir+'output/mL/results/ridge/permutation/SS/acc.csv')
pairCV=pd.read_csv(thisDir+'output/mL/results/ridge/permutation/CV/acc.csv')
permDS=pd.read_csv(thisDir+'output/mL/results/ridge/permutation/DS/acc.csv')
permBS=pd.read_csv(thisDir+'output/mL/results/ridge/permutation/BS/acc.csv')



#adding thinner lines to different task analysis figure

pairBS=pd.DataFrame()
for task in taskList:
    for test_task in taskList:
        if task==test_task:
            continue
        else:
            tmp=permBS[(permBS.train_task==task)&(permBS.test_task==test_task)]
            startIndex=0
            endIndex=55
            iterations=0
            cycle=55
            all_iter=pd.DataFrame()
            while endIndex<56000:
                #iterating through each permutationt to recreate the previous plots
                iterat_tmp=tmp[startIndex:endIndex]
                tmp_mu=iterat_tmp.groupby(['train_sub']).mean()
                tmp_mu['train_task']=task
                tmp_mu['test_task']=test_task
                tmp_mu['iteration']=iterations
                startIndex=startIndex+cycle
                endIndex=endIndex+cycle
                iterations=iterations+1
                all_iter=pd.concat([all_iter, tmp_mu])
            pairBS=pd.concat([pairBS,all_iter])
pairBS.reset_index(inplace=True)
pairBS.rename(columns={'train_sub':'sub'},inplace=True)
pairBS['Analysis']='Between'

pairDS=pd.DataFrame()
for task in taskList:
    tmp=permDS[(permDS['task']==task)]
    startIndex=0
    endIndex=55
    iterations=0
    all_iter=pd.DataFrame()
    while endIndex<56000:
        iterat_tmp=tmp[startIndex:endIndex]
        tmp_mu=iterat_tmp.groupby(['train_sub']).mean()
        tmp_mu['task']=task
        tmp_mu['iteration']=iterations
        startIndex=startIndex+55
        endIndex=endIndex+55
        iterations=iterations+1
        all_iter=pd.concat([all_iter,tmp_mu])
    pairDS=pd.concat([pairDS,all_iter])
pairDS.reset_index(inplace=True)
pairDS.rename(columns={'train_sub':'sub'},inplace=True)
pairDS['Analysis']='Between'

pairCV["iteration"] = permCV.groupby(['sub','task']).cumcount()

# %%
iterations=0
startIndex=0
endIndex=48
pairSS=pd.DataFrame()
while endIndex<48000:
    #iterating through each permutationt to recreate the previous plots
    iterat_tmp=permSS[startIndex:endIndex]
    iterat_tmp['iteration']=iterations
    startIndex=startIndex+48
    endIndex=endIndex+48
    iterations=iterations+1
    pairSS=pd.concat([pairSS, iterat_tmp])

# %%
pairSS
# Out:
#       train_task test_task    sub    acc  iteration
# 0          mixed     motor  MSC01  0.540          0
# 1          mixed       mem  MSC01  0.440          0
# 2          motor     mixed  MSC01  0.495          0
# 3          motor       mem  MSC01  0.330          0
# 4            mem     mixed  MSC01  0.395          0
# 5            mem     motor  MSC01  0.575          0
# 6          mixed     motor  MSC02  0.480          0
# 7          mixed       mem  MSC02  0.420          0
# 8          motor     mixed  MSC02  0.575          0
# 9          motor       mem  MSC02  0.630          0
# 10           mem     mixed  MSC02  0.280          0
# 11           mem     motor  MSC02  0.610          0
# 12         mixed     motor  MSC03  0.300          0
# 13         mixed       mem  MSC03  0.390          0
# 14         motor     mixed  MSC03  0.490          0
# 15         motor       mem  MSC03  0.365          0
# 16           mem     mixed  MSC03  0.650          0
# 17           mem     motor  MSC03  0.415          0
# 18         mixed     motor  MSC04  0.560          0
# 19         mixed       mem  MSC04  0.485          0
# 20         motor     mixed  MSC04  0.490          0
# 21         motor       mem  MSC04  0.545          0
# 22           mem     mixed  MSC04  0.490          0
# 23           mem     motor  MSC04  0.635          0
# 24         mixed     motor  MSC05  0.370          0
# 25         mixed       mem  MSC05  0.480          0
# 26         motor     mixed  MSC05  0.430          0
# 27         motor       mem  MSC05  0.400          0
# 28           mem     mixed  MSC05  0.375          0
# 29           mem     motor  MSC05  0.490          0
# ...          ...       ...    ...    ...        ...
# 47922      mixed     motor  MSC04  0.540        998
# 47923      mixed       mem  MSC04  0.345        998
# 47924      motor     mixed  MSC04  0.620        998
# 47925      motor       mem  MSC04  0.570        998
# 47926        mem     mixed  MSC04  0.560        998
# 47927        mem     motor  MSC04  0.515        998
# 47928      mixed     motor  MSC05  0.400        998
# 47929      mixed       mem  MSC05  0.580        998
# 47930      motor     mixed  MSC05  0.525        998
# 47931      motor       mem  MSC05  0.500        998
# 47932        mem     mixed  MSC05  0.560        998
# 47933        mem     motor  MSC05  0.330        998
# 47934      mixed     motor  MSC06  0.415        998
# 47935      mixed       mem  MSC06  0.425        998
# 47936      motor     mixed  MSC06  0.565        998
# 47937      motor       mem  MSC06  0.560        998
# 47938        mem     mixed  MSC06  0.465        998
# 47939        mem     motor  MSC06  0.305        998
# 47940      mixed     motor  MSC07  0.515        998
# 47941      mixed       mem  MSC07  0.595        998
# 47942      motor     mixed  MSC07  0.335        998
# 47943      motor       mem  MSC07  0.560        998
# 47944        mem     mixed  MSC07  0.485        998
# 47945        mem     motor  MSC07  0.435        998
# 47946      mixed     motor  MSC10  0.405        998
# 47947      mixed       mem  MSC10  0.430        998
# 47948      motor     mixed  MSC10  0.710        998
# 47949      motor       mem  MSC10  0.555        998
# 47950        mem     mixed  MSC10  0.340        998
# 47951        mem     motor  MSC10  0.500        998
#
# [47952 rows x 5 columns]

# %%
#fix CV file names
"""
motor=permCV[['task.1','acc.1','sub.1']]
mem=permCV[['task.2','acc.2','sub.2']]
mix=permCV[['task','acc','sub']]

motor.rename(columns={'task.1':'task', 'acc.1':'acc','sub.1':'sub'},inplace=True)
mem.rename(columns={'task.2':'task', 'acc.2':'acc','sub.2':'sub'},inplace=True)

p_CV=pd.concat([mix,mem,motor])
p_CV.to_csv(thisDir+'output/mL/results/ridge/permutation/CV/acc.csv', index=False)
"""

# %%
iterations=0
startIndex=0
endIndex=48
SS=pd.DataFrame()
while endIndex<48000:
    #iterating through each permutationt to recreate the previous plots
    iterat_tmp=permSS[startIndex:endIndex]
    iterat_tmp['iteration']=iterations
    startIndex=startIndex+48
    endIndex=endIndex+48
    iterations=iterations+1
    SS=pd.concat([SS, iterat_tmp])

# %%
tmp=permBS[(permBS.train_task=='mem')&(permBS.test_task=='motor')]

# %%
tmp
# Out:
#        train_task test_task train_sub test_sub    acc
# 5             mem     motor     MSC01    MSC02  0.495
# 11            mem     motor     MSC01    MSC03  0.610
# 17            mem     motor     MSC01    MSC04  0.490
# 23            mem     motor     MSC01    MSC05  0.515
# 29            mem     motor     MSC01    MSC06  0.495
# 35            mem     motor     MSC01    MSC07  0.615
# 41            mem     motor     MSC01    MSC10  0.500
# 47            mem     motor     MSC02    MSC01  0.530
# 53            mem     motor     MSC02    MSC03  0.490
# 59            mem     motor     MSC02    MSC04  0.495
# 65            mem     motor     MSC02    MSC05  0.435
# 71            mem     motor     MSC02    MSC06  0.520
# 77            mem     motor     MSC02    MSC07  0.500
# 83            mem     motor     MSC02    MSC10  0.530
# 89            mem     motor     MSC03    MSC01  0.495
# 95            mem     motor     MSC03    MSC02  0.555
# 101           mem     motor     MSC03    MSC04  0.500
# 107           mem     motor     MSC03    MSC05  0.455
# 113           mem     motor     MSC03    MSC06  0.530
# 119           mem     motor     MSC03    MSC07  0.430
# 125           mem     motor     MSC03    MSC10  0.520
# 131           mem     motor     MSC04    MSC01  0.465
# 137           mem     motor     MSC04    MSC02  0.490
# 143           mem     motor     MSC04    MSC03  0.460
# 149           mem     motor     MSC04    MSC05  0.490
# 155           mem     motor     MSC04    MSC06  0.520
# 161           mem     motor     MSC04    MSC07  0.580
# 167           mem     motor     MSC04    MSC10  0.480
# 173           mem     motor     MSC05    MSC01  0.570
# 179           mem     motor     MSC05    MSC02  0.540
# ...           ...       ...       ...      ...    ...
# 335825        mem     motor     MSC04    MSC07  0.510
# 335831        mem     motor     MSC04    MSC10  0.510
# 335837        mem     motor     MSC05    MSC01  0.450
# 335843        mem     motor     MSC05    MSC02  0.460
# 335849        mem     motor     MSC05    MSC03  0.475
# 335855        mem     motor     MSC05    MSC04  0.465
# 335861        mem     motor     MSC05    MSC06  0.515
# 335867        mem     motor     MSC05    MSC07  0.550
# 335873        mem     motor     MSC05    MSC10  0.525
# 335879        mem     motor     MSC06    MSC01  0.495
# 335885        mem     motor     MSC06    MSC02  0.510
# 335891        mem     motor     MSC06    MSC03  0.495
# 335897        mem     motor     MSC06    MSC04  0.500
# 335903        mem     motor     MSC06    MSC05  0.475
# 335909        mem     motor     MSC06    MSC07  0.465
# 335915        mem     motor     MSC06    MSC10  0.480
# 335921        mem     motor     MSC07    MSC01  0.475
# 335927        mem     motor     MSC07    MSC02  0.490
# 335933        mem     motor     MSC07    MSC03  0.505
# 335939        mem     motor     MSC07    MSC04  0.500
# 335945        mem     motor     MSC07    MSC05  0.425
# 335951        mem     motor     MSC07    MSC06  0.475
# 335957        mem     motor     MSC07    MSC10  0.500
# 335963        mem     motor     MSC10    MSC01  0.500
# 335969        mem     motor     MSC10    MSC02  0.545
# 335975        mem     motor     MSC10    MSC03  0.535
# 335981        mem     motor     MSC10    MSC04  0.445
# 335987        mem     motor     MSC10    MSC05  0.450
# 335993        mem     motor     MSC10    MSC06  0.485
# 335999        mem     motor     MSC10    MSC07  0.435
#
# [56000 rows x 5 columns]
