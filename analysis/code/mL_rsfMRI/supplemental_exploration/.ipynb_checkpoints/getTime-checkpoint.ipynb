# %%
import pandas as pd
df = pd.DataFrame([])
subs=['MSC01','MSC02','MSC03', 'MSC04','MSC05','MSC06','MSC07', 'MSC10']
for i in subs:
    tmp_df=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/frames/'+i+'.csv')
    tmp_df['sub']=i
    df=df.append(tmp_df, ignore_index=False)
df.index.name='sess'

# %%
import pandas as pd
condind_df = pd.DataFrame([])
subs=['MSC01','MSC02','MSC03', 'MSC04','MSC05','MSC06','MSC07', 'MSC10']
for i in subs:
    tmp_df=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/data/time/'+i+'.csv')
    tmp_df['sub']=i
    condind_df=condind_df.append(tmp_df, ignore_index=False)
condind_df.index.name='sess'

# %%
condind_df.head()
# Out:
#       mem  AllGlass  AllSemantic  rest  motor    sub
# sess
# 0     313       123          138   523    102  MSC01
# 1     284       124          133   717    118  MSC01
# 2     316        98          125   732     85  MSC01
# 3     316       132           96   778     96  MSC01
# 4     266        97          110   710     85  MSC01

# %%
time5 = pd.DataFrame([])
time4 = pd.DataFrame([])

m5=len(df[df.motor > 136]) 
m4=len(df[df.motor > 109])

me5=len(df[df.mem > 136]) 
me4=len(df[df.mem > 109]) 

g5=len(df[df.mixed > 136]) 
g4=len(df[df.mixed > 109]) 

r5=len(df[df.rest > 136]) 
r4=len(df[df.rest > 109]) 
      
time5=time5.append({'motor': m5,'mem': me5, 'mixed':g5, 'rest':r5,'time':136}, ignore_index=True)
time5=time5.append({'motor': m4,'mem': me4, 'mixed':g4, 'rest':r4, 'time':109}, ignore_index=True)

#time5.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/mLminQuality/results/time/counts.csv')

# %%
time5
# Out:
#     mem  mixed  motor  rest   time
# 0  73.0   77.0   54.0  80.0  136.0
# 1  77.0   77.0   67.0  80.0  109.0

# %%
motor_df=df[['motor', 'sub']]
mem_df=df[['mem', 'sub']]
mixed_df=df[['mixed', 'sub']]
rest_df=df[['rest', 'sub']]

# %%
m_df=motor_df.loc[motor_df['motor']>135]
me_df=mem_df.loc[mem_df['mem']>135]

g_df=mixed_df.loc[glass_df['mixed']>135]
s_df=rest_df.loc[sem_df['rest']>135]

# %%
m_df.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/mLminQuality/results/time/motor.csv')
me_df.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/mLminQuality/results/time/mem.csv')
g_df.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/mLminQuality/results/time/glass.csv')
s_df.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/mLminQuality/results/time/semantic.csv')

# %%
s_df
# Out:
#       AllSemantic    sub
# sess
# 0             138  MSC01
# 7             141  MSC02
# 0             141  MSC03
# 6             136  MSC04
# 1             137  MSC05
# 2             137  MSC05
# 6             136  MSC05
# 2             140  MSC06
# 3             140  MSC06
# 5             138  MSC06
# 8             141  MSC06
# 0             141  MSC07
# 2             141  MSC07
# 3             140  MSC07
# 8             140  MSC07
# 8             136  MSC10

# %%
mem_shape=mem_df.pivot(columns='sub', values='mem')
motor_shape=motor_df.pivot(columns='sub', values='motor')
mixed_shape=mixed_df.pivot(columns='sub', values='mixed')
rest_shape=rest_df.pivot(columns='sub', values='rest')

# %%
mem_shape.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/frames/mem_reshaped.csv')
motor_shape.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/frames/motor_reshaped.csv')
mixed_shape.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/frames/mixed_reshaped.csv')
rest_shape.to_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/results/frames/rest_reshaped.csv')

# %%
mem_shape
# Out:
# sub   MSC01  MSC02  MSC03  MSC04  MSC05  MSC06  MSC07  MSC10
# sess
# 0       328    338    352    290    343    332    355    274
# 1       299    350    339    356    343    349    346    170
# 2       336    320    335    165    356    359    353    284
# 3       330    336    237    284    359    359    352    288
# 4       274    352    129    353    350    357    308    274
# 5       201    308      0    320    323    361    338     90
# 6       309    344    122    340    350    360    346    134
# 7       290    333      0    345    341    240    353    292
# 8       201    357    150    343    356    337    340    312
# 9       317    322    111    349    349    355    305    336

# %%
import seaborn as sns
import pandas as pd
import numpy as np
mem_shape=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/old/results/frames/mem_reshaped.csv')
motor_shape=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/old/results/frames/motor_reshaped.csv')
mixed_shape=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/old/results/frames/mixed_reshaped.csv')
rest_shape=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/old/results/frames/rest_reshaped.csv')

# %%
sns.heatmap(mem_shape, vmin=109)

# %%
sns.heatmap(mixed_shape, vmin=109)

# %%
sns.heatmap(rest_shape, vmin=109)

# %%
sns.heatmap(motor_shape, vmin=109)

# %%
Lmem=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/old/results/frames/mem_reshaped.csv')
Lmotor=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/old/results/frames/motor_reshaped.csv')
Lmixed=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/old/results/frames/mixed_reshaped.csv')
Lrest=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/output/old/results/frames/rest_reshaped.csv')

# %%
Smem=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/data/time/mem_reshaped.csv')
Smotor=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/data/time/motor_reshaped.csv')
Sglass=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/data/time/glass_reshaped.csv')
Ssem=pd.read_csv('/Users/Alexis/Desktop/MSC_Alexis/analysis/data/time/semantic_reshaped.csv')

# %%
Lmixed
# Out:
#    sess  MSC01  MSC02  MSC03  MSC04  MSC05  MSC06  MSC07  MSC10
# 0     0    356    269    368    329    300    358    367    277
# 1     1    355    334    337    221    347    327    359    177
# 2     2    305    311    251    300    372    379    345    319
# 3     3    287    281    211    223    363    372    363    249
# 4     4    272    288    288    345    342    365    350    244
# 5     5    230    261    175    217    323    373    351    339
# 6     6    273    256    243    367    362    355    339    139
# 7     7    280    372     58    341    303     60    369    200
# 8     8     84    356    212    361    334    363    367    342
# 9     9    268    356    301    310    268    339    332    203

# %%
Lmem
# Out:
#    sess  MSC01  MSC02  MSC03  MSC04  MSC05  MSC06  MSC07  MSC10
# 0     0    328    338    352    290    343    332    355    274
# 1     1    299    350    339    356    343    349    346    170
# 2     2    336    320    335    165    356    359    353    284
# 3     3    330    336    237    284    359    359    352    288
# 4     4    274    352    129    353    350    357    308    274
# 5     5    201    308      0    320    323    361    338     90
# 6     6    309    344    122    340    350    360    346    134
# 7     7    290    333      0    345    341    240    353    292
# 8     8    201    357    150    343    356    337    340    312
# 9     9    317    322    111    349    349    355    305    336

# %%
Lrest
# Out:
#    sess  MSC01  MSC02  MSC03  MSC04  MSC05  MSC06  MSC07  MSC10
# 0     0    523    531    699    722    685    662    455    511
# 1     1    717    793    796    739    740    806    691    158
# 2     2    732    780    756    183    645    812    666    433
# 3     3    778    789    645    360    767    818    399    743
# 4     4    710    650    534    728    769    812    623    628
# 5     5    531    535    364    695    642    791    430    336
# 6     6    551    812    475    780    768    808    796    545
# 7     7    670    795    535    772    712    723    804    526
# 8     8    420    798    661    744    744    643    645    766
# 9     9    635    767    710    643    789    792    554    643

# %%
min(Lmem)
# Out:
# 'MSC01'

# %%
Smotor
# Out:
#    sess  MSC01  MSC02  MSC03  MSC04  MSC05  MSC06  MSC07  MSC10
# 0     0    102    118    126    105    128    114     67     95
# 1     1    118    103    130    118    115    126     85     84
# 2     2     85    134     96     64    105    104     61    138
# 3     3     96    132    134     96    129    137     78    115
# 4     4     85    132     77    136    105    123     87     99
# 5     5     96    139     71     76     62    127      0    116
# 6     6     86    134     81    122    119    126     92     85
# 7     7    111    132    114    127     86      0     98     92
# 8     8     47    127     94    120    119    120    107    138
# 9     9     97    130     98    130     92    124     61    130

# %%
Smem
# Out:
#    sess  MSC01  MSC02  MSC03  MSC04  MSC05  MSC06  MSC07  MSC10
# 0     0    313    319    340    288    331    315    334    269
# 1     1    284    331    327    341    326    336    332    168
# 2     2    316    314    329    164    336    342    335    283
# 3     3    316    321    233    280    340    344    336    282
# 4     4    266    340    124    338    336    340    299    267
# 5     5    196    297      0    312    314    342    328     90
# 6     6    301    333    120    332    333    344    338    134
# 7     7    281    321      0    328    332    230    339    285
# 8     8    201    339    143    331    339    330    323    303
# 9     9    303    308    107    332    338    342    302    322
