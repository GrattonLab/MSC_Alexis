# %%
import matlab.engine
import numpy as np
#this function runs a matlab script that randomly selects frames in chunks and converts them into a numpy array 
def getFrames(sub='MSC01', num=5, task='mem'):
    nrois=333
    eng=matlab.engine.start_matlab()
    parcel=eng.reframe(sub, num, task)
    fileFC=np.asarray(parcel)
    #Replace nans and infs with zero
    fileFC=np.nan_to_num(fileFC)
    if fileFC.ndim<3:
        return np.empty([])
    else:
        nsess=fileFC.shape[2]
    #Consistent parameters to use for editing datasets
    #Index upper triangle of matrix
        mask=np.triu_indices(nrois,1)
        ds=np.empty((nsess, int(nrois*(nrois-1)/2)))
        count=0
    #Loop through all 10 days to reshape correlations into linear form
        for sess in range(nsess):
            tmp=fileFC[:,:,sess]
            ds[count]=tmp[mask]
            count=count+1
    return ds

# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:

from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import KFold
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
import numpy as np
import os
import sys
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import classification
#import other python scripts for further anlaysis
#import reshape
#import results
import warnings
warnings.filterwarnings("ignore")
# Initialization of directory information:
thisDir = os.path.expanduser('~/Desktop/MSC_Alexis/analysis/')
dataDir=thisDir+'data/mvpa_data/'
# Subjects and tasks
framesList=[5,25,50,100,150,200,250,300,350]

#taskList=['mixed', 'motor','mem']
taskList=['mixed','mem']
subList=['MSC01','MSC02','MSC03','MSC04','MSC05','MSC06','MSC07','MSC10']

#all possible combinations of subs and tasks
subsComb=(list(itertools.permutations(subList, 2)))
tasksComb=(list(itertools.permutations(taskList, 2)))
#DS combination
DSvars=list(itertools.product(list(subsComb),list(taskList)))
##SS combination
SSvars=list(itertools.product(list(subList),list(tasksComb)))
#BS combination
BSvars=list(itertools.product(list(subsComb),list(tasksComb)))


"""
initializes what type of analysis you would like to do and what classifier you would like to use. For now classifier options
are svm:linear svm, logreg: logistic regression, and ridge:ridge regression. Analysis is the type of analysis you wanted
to run. DS--different subject same task; SS--same subject different task; BS--different subject different task.
Each analysis will concatenate across subjects and make a dataframe.
"""
def storeResults():
    all_permutations=pd.DataFrame()
    for i in range(20):
        #df=classifyCV()
        df=classifyDS()
        all_permutations=pd.concat([all_permutations,df])
    all_permutations.to_csv(thisDir+'output/mL/results/ridge/permutation/DS/resampleFrames.csv',index=False)


def classifyDS():
    """
    Classifying different subjects (DS) along the same task

    Parameters
    -------------
    classifier : str
            The statistical method used for classification
    analysis : str
            The type of analysis to be conducted

    Returns
    -------------
    dfDS : DataFrame
        Dataframe consisting of average accuracy across all subjects

    """
    
    
    tmp_df=pd.DataFrame(DSvars, columns=['sub','task'])
    df=pd.DataFrame()
    for num in framesList:
        dfDS=pd.DataFrame(subsComb,columns=['train_sub','test_sub'])
        #tmp=pd.DataFrame(subsComb, columns=['Train','Test'])
        #dfDS[['train_sub','test_sub']]=pd.DataFrame(tmp_df['sub'].tolist())
        #dfDS['task']=tmp_df['task']
        acc_scores_per_task=[]
        for index, row in dfDS.iterrows():
            score=model('DS',num,train_sub=row['train_sub'], test_sub=row['test_sub'], train_task='mem', test_task='mem')
            acc_scores_per_task.append(score)
        dfDS['acc']=acc_scores_per_task
        dfDS['frames']=num
        df=pd.concat([df,dfDS])
    return df
def classifySS(analysis):
    """
    Classifying the same subject (SS) along a different task

    Parameters
    -------------
    classifier : str
            The statistical method used for classification
    analysis : str
            The type of analysis to be conducted

    Returns
    -------------
    dfSS : DataFrame
        Dataframe consisting of average accuracy across all subjects

    """
    
    
    tmp_df=pd.DataFrame(SSvars, columns=['sub','task'])
    df=pd.DataFrame()
    for num in framesList:
        dfSS=pd.DataFrame()
        dfSS[['train_task','test_task']]=pd.DataFrame(tmp_df['task'].tolist())
        dfSS['sub']=tmp_df['sub']
        acc_scores_per_task=[]
        for index, row in dfSS.iterrows():
            score=model('SS', num, train_sub=row['sub'], test_sub=row['sub'], train_task=row['train_task'], test_task=row['test_task'])
            acc_scores_per_task.append(score)
        dfSS['acc']=acc_scores_per_task
        dfSS['frames']=num
        df=pd.concat([df,dfSS])
    #save accuracy
    return df
def classifyBS():
    """
    Classifying different subjects (BS) along different tasks

    Parameters
    -------------
    classifier : str
            The statistical method used for classification
    analysis : str
            The type of analysis to be conducted

    Returns
    -------------
    dfBS : DataFrame
        Dataframe consisting of average accuracy across all subjects

    """
    tmp_df=pd.DataFrame(BSvars, columns=['sub','task'])
    df=pd.DataFrame()
    for num in framesList:
        acc_scores_per_task=[]
        dfBS=pd.DataFrame()
        dfBS[['train_task','test_task']]=pd.DataFrame(tmp_df['task'].tolist())
        dfBS[['train_sub', 'test_sub']]=pd.DataFrame(tmp_df['sub'].tolist())
        for index, row in dfBS.iterrows():
            score=model('BS', num, train_sub=row['train_sub'], test_sub=row['test_sub'], train_task=row['train_task'], test_task=row['test_task'])
            acc_scores_per_task.append(score)
            acc_scores_per_frame.append(num)
        dfBS['acc']=acc_scores_per_task
        dfBS['frames']=num
        df=pd.concat([df,dfBS])
    #save accuracy
    return df

def classifyCV():
    """
    Classifying same subjects (CV) along the same task

    Parameters
    -------------
    classifier : str
            The statistical method used for classification
    analysis : str
            The type of analysis to be conducted

    Returns
    -------------
    dfCV : DataFrame
        Dataframe consisting of average accuracy across all subjects

        """
    clf=RidgeClassifier()
    acc_scores_per_task=[]
    subs_per_task=[]
    task_per_task=[]
    frames_per_task=[]
    for num in framesList:
        for task in taskList:
            for sub in subList:
                taskFC=getFrames(sub,num,task)
                restFC=getFrames(sub,num, 'rest')
                if taskFC.size==1 or restFC.size==1:
                    mu='9999'
                    print('subject '+sub+ ' has no data for frame '+str(num))
                else:
                    folds=taskFC.shape[0]
                    x_train, y_train=classification.concateFC(taskFC, restFC)
                    CVscores=cross_val_score(clf, x_train, y_train, cv=folds)
                    mu=CVscores.mean()
                    acc_scores_per_task.append(mu)
                    subs_per_task.append(sub)
                    task_per_task.append(task)
                    frames_per_task.append(num)
    dfCV=pd.DataFrame({'train_sub':subs_per_task,'train_task':task_per_task, 'acc':acc_scores_per_task, 'frames':frames_per_task, 'analysis':'CV'})
    return dfCV
def model(analysis, num,train_sub, test_sub, train_task, test_task):
    """
    Preparing machine learning model with appropriate data

    Parameters
    -------------
    classifier : str
            The statistical method used for classification
    analysis : string
            The type of analysis to be conducted
    train_sub : str
            Subject name for training
    test_sub : str
            Subject name for testing
    train_task : str
            Task name for training
    test_task : str
            Task name for testing

    Returns
    -------------
    total_score : float
            Average accuracy of all folds

    """
    clf=RidgeClassifier()
    df=pd.DataFrame()
    taskFC=getFrames(train_sub,num,train_task)
    restFC=getFrames(train_sub,num, 'rest')
    #if the file returns a 1 dimensional empty array there weren't enough frames for sub
    if taskFC.size==1 or restFC.size==1:
        total_score='9999'
        print('subject '+train_sub+ ' does not have data for frame '+str(num))
    #if either rest or task FC has less than 5 samples don't use
    elif taskFC.shape[0]<5 or restFC.shape[0]<5:
        total_score='9999'
        print('subject '+train_sub+ ' does not have days for frame '+str(num))
    else:
    #if your subs are the same
        if train_sub==test_sub:
            test_taskFC=classification.matFiles(dataDir+test_task+'/'+test_sub+'_parcel_corrmat.mat')
            test_restFC=classification.matFiles(dataDir+'rest/'+test_sub+'_parcel_corrmat.mat')
            total_score=CV_folds(clf, analysis, taskFC, restFC, test_taskFC, test_restFC)
        else:
            test_taskFC=classification.matFiles(dataDir+test_task+'/'+test_sub+'_parcel_corrmat.mat')
            test_restFC=classification.matFiles(dataDir+'rest/'+test_sub+'_parcel_corrmat.mat')
            total_score=CV_folds(clf, analysis, taskFC, restFC, test_taskFC, test_restFC)
    return total_score
#Calculate acc of cross validation within sub within task
def CV_folds(clf, analysis, taskFC, restFC, test_taskFC, test_restFC):
    """
    Cross validation to train and test using nested loops

    Parameters
    -----------
    clf : obj
        Machine learning algorithm
    analysis : str
        Analysis type
    taskFC, restFC, test_taskFC, test_restFC : array_like
        Input arrays, training and testing set of task and rest FC
    Returns
    -----------
    total_score : float
        Average accuracy across folds
    acc_score : list
        List of accuracy for each outer fold
    """

    loo = LeaveOneOut()
    taskSize=taskFC.shape[0]
    restSize=restFC.shape[0]
    t = np.ones(taskSize, dtype = int)
    r=np.zeros(restSize, dtype=int)
    if analysis=='SS':
        df=pd.DataFrame()
        acc_score=[]
        for train_index, test_index in loo.split(taskFC):
            Xtrain_rest, Xtest_rest=restFC[train_index], test_restFC[test_index]
            Xtrain_task=taskFC[train_index]
            ytrain_rest=r[train_index]
            ytrain_task=t[train_index]
            X_tr=np.concatenate((Xtrain_task, Xtrain_rest))
            y_tr = np.concatenate((ytrain_task,ytrain_rest))
            clf.fit(X_tr,y_tr)
            tmpdf=pd.DataFrame()
            acc_scores_per_fold=[]
            for t_index, te_index in loo.split(test_taskFC):
                Xtest_task=test_taskFC[te_index]
                X_Test = np.concatenate((Xtest_task, Xtest_rest))
                y_Test = np.array([1, 0])
                #test set
                clf.predict(X_Test)
                #Get accuracy of model
                ACCscores=clf.score(X_Test,y_Test)
                acc_scores_per_fold.append(ACCscores)
            tmpdf['inner_fold']=acc_scores_per_fold
            score=tmpdf['inner_fold'].mean()
            acc_score.append(score)
        df['outer_fold']=acc_score
        total_score=df['outer_fold'].mean()
    else:
        df=pd.DataFrame()
        acc_score=[]
        #fold each training set
        for train_index, test_index in loo.split(taskFC):
            Xtrain_rest=restFC[train_index]
            Xtrain_task=taskFC[train_index]
            ytrain_rest=r[train_index]
            ytrain_task=t[train_index]
            X_tr=np.concatenate((Xtrain_task, Xtrain_rest))
            y_tr = np.concatenate((ytrain_task,ytrain_rest))
            clf.fit(X_tr,y_tr)
            tmpdf=pd.DataFrame()
            acc_scores_per_fold=[]
            #fold each testing set
            for t_index, te_index in loo.split(test_taskFC):
                Xtest_rest=test_restFC[te_index]
                Xtest_task=test_taskFC[te_index]
                X_te=np.concatenate((Xtest_task, Xtest_rest))
                y_te=np.array([1, 0])
                #test set
                clf.predict(X_te)
                #Get accuracy of model
                ACCscores=clf.score(X_te,y_te)
                acc_scores_per_fold.append(ACCscores)
            tmpdf['inner_fold']=acc_scores_per_fold
            score=tmpdf['inner_fold'].mean()
            acc_score.append(score)
        df['outer_fold']=acc_score
        total_score=df['outer_fold'].mean()

    return total_score
    #return df

# %%
storeResults()
# Out:
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# ...
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 200
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 250
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC03 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC10 does not have days for frame 300
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC01 does not have data for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC02 does not have days for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC03 does not have data for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC04 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC07 does not have days for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350
# subject MSC10 does not have data for frame 350

# %%
dfDS=classifyDS()

# %%
import classification
import numpy as np
train=getFrames('MSC01',175,'rest')
test=classification.matFiles(dataDir+'rest/MSC01_parcel_corrmat.mat')

# %%
dfDS=pd.DataFrame()

# %%
tmp_df=pd.DataFrame(DSvars, columns=['sub','task'])
dfDS[['train_sub','test_sub']]=pd.DataFrame(tmp_df['sub'].tolist())
dfDS['task']=tmp_df['task']

# %%
dfDS
# Out:
#     train_sub test_sub   task
# 0       MSC01    MSC02  mixed
# 1       MSC01    MSC02    mem
# 2       MSC01    MSC03  mixed
# 3       MSC01    MSC03    mem
# 4       MSC01    MSC04  mixed
# ..        ...      ...    ...
# 107     MSC10    MSC05    mem
# 108     MSC10    MSC06  mixed
# 109     MSC10    MSC06    mem
# 110     MSC10    MSC07  mixed
# 111     MSC10    MSC07    mem
#
# [112 rows x 3 columns]

# %%
subsComb=(list(itertools.permutations(subList, 2)))

# %%
tmp=pd.DataFrame(subsComb, columns=['Train','Test'])

# %%
tmp
# Out:
#     Train   Test
# 0   MSC01  MSC02
# 1   MSC01  MSC03
# 2   MSC01  MSC04
# 3   MSC01  MSC05
# 4   MSC01  MSC06
# 5   MSC01  MSC07
# 6   MSC01  MSC10
# 7   MSC02  MSC01
# 8   MSC02  MSC03
# 9   MSC02  MSC04
# 10  MSC02  MSC05
# 11  MSC02  MSC06
# 12  MSC02  MSC07
# 13  MSC02  MSC10
# 14  MSC03  MSC01
# 15  MSC03  MSC02
# 16  MSC03  MSC04
# 17  MSC03  MSC05
# 18  MSC03  MSC06
# 19  MSC03  MSC07
# 20  MSC03  MSC10
# 21  MSC04  MSC01
# 22  MSC04  MSC02
# 23  MSC04  MSC03
# 24  MSC04  MSC05
# 25  MSC04  MSC06
# 26  MSC04  MSC07
# 27  MSC04  MSC10
# 28  MSC05  MSC01
# 29  MSC05  MSC02
# 30  MSC05  MSC03
# 31  MSC05  MSC04
# 32  MSC05  MSC06
# 33  MSC05  MSC07
# 34  MSC05  MSC10
# 35  MSC06  MSC01
# 36  MSC06  MSC02
# 37  MSC06  MSC03
# 38  MSC06  MSC04
# 39  MSC06  MSC05
# 40  MSC06  MSC07
# 41  MSC06  MSC10
# 42  MSC07  MSC01
# 43  MSC07  MSC02
# 44  MSC07  MSC03
# 45  MSC07  MSC04
# 46  MSC07  MSC05
# 47  MSC07  MSC06
# 48  MSC07  MSC10
# 49  MSC10  MSC01
# 50  MSC10  MSC02
# 51  MSC10  MSC03
# 52  MSC10  MSC04
# 53  MSC10  MSC05
# 54  MSC10  MSC06
# 55  MSC10  MSC07
